# %%
from mlp import *
# Out:
#    8   1   0   1   4   3
#    1   8   0   0   0   0
#    0   0  20   0   7   0
#    0   0   0  27   2   2
#    4   0   5   0  38   0
#    0   5   0   4   1  33
# False Positives
#  [ 5  6  5  5 14  5]
# False Negetives
#  [ 9  1  7  4  9 10]
# True Positives
#  [ 8  8 20 27 38 33]
# True Negetives
#  [152 159 142 138 113 126]
# Sensitivity
#  [0.47058824 0.88888889 0.74074074 0.87096774 0.80851064 0.76744186]
# Specificity
#  [0.96815287 0.96363636 0.96598639 0.96503497 0.88976378 0.96183206]
# Precision
#  [0.61538462 0.57142857 0.8        0.84375    0.73076923 0.86842105]
# Recall
#  [0.47058824 0.88888889 0.74074074 0.87096774 0.80851064 0.76744186]
# Áccuracy
# [0.91954023 0.95977011 0.93103448 0.94827586 0.86781609 0.9137931 ]
# FScore
# [0.53333333 0.69565217 0.76923077 0.85714286 0.76767677 0.81481481]
# Çohen Kappa
# 0.7122064174660933
#    9   4   0   0   4   0
#    1  19   0   0   0   1
#    0   0  36   0   4   0
#    0   0   0  24   0   4
#    1   0   0   0  36   2
# ...
